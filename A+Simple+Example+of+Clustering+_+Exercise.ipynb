# %% [markdown]
# <a href="https://colab.research.google.com/github/Broraps/Data-Science/blob/main/A%2BSimple%2BExample%2Bof%2BClustering%2B_%2BExercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A Simple Example of Clustering

# %% [markdown]
# You are given much more country data. Using the same methodology as the one in the lecture, group all the countries in 2 clusters.
#
# Try with other numbers of clusters and see if they match your expectations. Maybe 7 is going to be a cool one!
#
# Plot the data using the <i> c </i> parameter to separate the data by the clusters we defined.
#
# <i> Note: c stands for color <i>

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'Countries.csv'</i>.

# %%
raw_data = pd.read_csv('/content/Countries-exercise.csv')
raw_data.head()
# Out:
#           name  Longitude   Latitude
# 0        Aruba -69.982677  12.520880
# 1  Afghanistan  66.004734  33.835231
# 2       Angola  17.537368 -12.293361
# 3     Anguilla -63.064989  18.223959
# 4      Albania  20.049834  41.142450

# %% [markdown]
# ## Plot the data

# %% [markdown]
# Plot the <i>'Longtitude'</i> and <i>'Latitude'</i> columns.

# %%
data = raw_data.copy()
plt.scatter(data['Longitude'], data['Latitude'])
plt.xlim(-180,180)
plt.ylim(-90, 90)
plt.show()

# %% [markdown]
# ## Select the features

# %% [markdown]
# Create a copy of that data and remove all parameters apart from <i>Longitude</i> and <i>Latitude</i>.

# %%
x = data.iloc[:,1:3]

# %% [markdown]
# ## Clustering

# %% [markdown]
# Assume there are only two clusters.

# %%
kmeans = KMeans(4)

# %%
kmeans.fit(x)
# Out:
# KMeans(n_clusters=4)

# %% [markdown]
# ### Clustering Resutls

# %%
indentified_clusters = kmeans.fit_predict(x)
indentified_clusters
# Out:
# array([1, 2, 2, 1, 0, 0, 0, 2, 1, 2, 1, 2, 3, 2, 1, 3, 0, 2, 2, 0, 0, 0,
#        3, 0, 2, 1, 1, 0, 1, 0, 1, 1, 1, 1, 1, 3, 3, 2, 2, 0, 1, 3, 0, 2,
#        2, 2, 1, 1, 2, 0, 1, 1, 1, 1, 0, 0, 0, 0, 2, 1, 0, 1, 0, 1, 2, 2,
#        0, 0, 2, 0, 3, 1, 0, 0, 3, 2, 0, 2, 0, 0, 0, 0, 0, 2, 0, 1, 0, 1,
#        3, 1, 3, 2, 1, 0, 1, 0, 3, 0, 2, 3, 2, 0, 2, 2, 0, 2, 0, 1, 0, 2,
#        3, 2, 2, 2, 2, 3, 1, 1, 3, 0, 2, 3, 2, 0, 0, 1, 0, 2, 2, 0, 0, 0,
#        3, 1, 0, 0, 0, 2, 2, 1, 3, 0, 0, 0, 3, 0, 3, 3, 2, 0, 1, 2, 2, 3,
#        2, 3, 0, 3, 0, 1, 1, 0, 0, 2, 3, 3, 2, 2, 1, 1, 1, 3, 3, 3, 0, 1,
#        3, 0, 1, 2, 1, 2, 0, 3, 2, 0, 2, 2, 2, 0, 3, 1, 0, 3, 0, 1, 0, 2,
#        2, 1, 0, 2, 1, 0, 0, 0, 2, 1, 2, 2, 1, 2, 0, 3, 2, 2, 3, 1, 1, 0,
#        0, 3, 2, 2, 0, 1, 1, 2, 0, 1, 1, 1, 1, 3, 3, 1, 1, 2, 2, 2, 2],
#       dtype=int32)

# %%
data_with_clusters = data.copy()
data_with_clusters['Cluster'] = indentified_clusters
data_with_clusters.head()
# Out:
#           name  Longitude   Latitude  Cluster
# 0        Aruba -69.982677  12.520880        1
# 1  Afghanistan  66.004734  33.835231        2
# 2       Angola  17.537368 -12.293361        2
# 3     Anguilla -63.064989  18.223959        1
# 4      Albania  20.049834  41.142450        0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Longitude'].plot(kind='hist', bins=20, title='Longitude')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Latitude'].plot(kind='hist', bins=20, title='Latitude')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Cluster'].plot(kind='hist', bins=20, title='Cluster')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# ...

# %% [markdown]
# Did you remember to use the <i> c </i> parameter to separate the data by the clusters we defined?

# %%
plt.scatter(data_with_clusters['Longitude'], data_with_clusters['Latitude'], c=data_with_clusters['Cluster'], cmap = 'rainbow')
plt.xlim(-180,180)
plt.ylim(-90, 90)
plt.show()

# %% [markdown]
# If you haven't, go back and play around with the number of clusters.
#
# Try 3, 7 and 8 and see if the results match your expectations!
